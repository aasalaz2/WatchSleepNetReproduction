# %% [markdown]
# <a href="https://colab.research.google.com/github/aasalaz2/WatchSleepNetReproduction/blob/main/WatchSleepNet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Mount Google Drive
# ---

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

# %% [markdown]
# # Load Project Directory

# %%
project_dir = "/content/drive/MyDrive/CS598/WatchSleepNet_project"
data_dir = f"{project_dir}/data"
repo_dir = f"{project_dir}/WatchSleepNet_public"
# %cd $project_dir

# %%
# %cd $repo_dir
# !pip install -r <(grep -v "numpy" requirements.txt)
# !pip install mne==1.6.1

# %% [markdown]
# # Only Run to Download Datasets

# %%
# !apt-get install -y ruby-full
# !gem install nsrr --no-document

# %% [markdown]
# ## Download SHHS & MESA

# %%
# !nsrr download \
    shhs/polysomnography/edfs/shhs1 \
    shhs/polysomnography/annotations-events-profusion/shhs1 \
    mesa/polysomnography/edfs \
    mesa/polysomnography/annotations-events-profusion \
    --fast

# %%
# !wget -r -N -c -np --user aas15 --ask-password \
  -nH --cut-dirs=3 -R "index.html*" \
  https://physionet.org/files/dreamt/2.1.0/data_100Hz/

# %% [markdown]
# cd into Repo

# %%
# %cd $repo_dir

# %% [markdown]
# # Extract IBI from DREAMT dataset

# %%
# !python dataset_preparation/dreamt/dreamt_extract_ibi_se.py

# %% [markdown]
# # Extract PPG from MESA and ECG from SHHS

# %%
# !python dataset_preparation/public_datasets/mesa_extract_ppg.py

# %%
# !python dataset_preparation/public_datasets/shhs_extract_ecg.py

# %% [markdown]
# # Extract IBI from MESA and SHHS

# %%
# !python dataset_preparation/public_datasets/extract_and_save_ibi.py

# %% [markdown]
# # Run Experiments

# %% [markdown]
# Before running experiments enter the modeling folder.

# %%
# %cd modeling/

# %% [markdown]
# ### Experiment 1: Transfer Learning

# %%
# !python train_transfer.py > output.txt 2>&1

# %% [markdown]
# ### Experiment 2: WatchSleepNet Ablation Study

# %%
# !python watchsleepnet_cv_ablation.py
